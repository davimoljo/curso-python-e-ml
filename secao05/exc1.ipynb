# %%
import pickle

from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
from sklearn.tree import DecisionTreeClassifier
from yellowbrick.classifier import ConfusionMatrix

# %%
with open('cover_type.pkl', 'rb') as f:
    X_train, y_train, X_test, y_test = pickle.load(f)

# %%
X_train.shape, y_train.shape
# Out:
# ((7500, 53), (7500,))

# %%
X_test.shape, y_test.shape
# Out:
# ((2500, 53), (2500,))

# %%
tree_classifier = DecisionTreeClassifier(criterion='gini', random_state=0)
tree_classifier.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(random_state=0)

# %%
y_pred = tree_classifier.predict(X_test)
y_pred
# Out:
# array([4, 4, 1, ..., 6, 4, 5])

# %%
accuracy_score(y_test, y_pred)
# Out:
# 0.7172

# %%
from yellowbrick.classifier import ConfusionMatrix
cm = ConfusionMatrix(tree_classifier)
cm.fit(X_train, y_train)
cm.score(X_test, y_test)
# Out:
# 0.7172

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.43      0.35      0.39        34
#            1       0.44      0.50      0.47        16
#            2       0.49      0.58      0.53        67
#            3       0.64      0.64      0.64        87
#            4       0.76      0.77      0.77      1230
#            5       0.74      0.70      0.72       156
#            6       0.69      0.68      0.69       910
#
#     accuracy                           0.72      2500
#    macro avg       0.60      0.60      0.60      2500
# weighted avg       0.72      0.72      0.72      2500

# %%
tree_classifier = RandomForestClassifier(criterion='entropy', n_estimators=150, random_state=0)
tree_classifier.fit(X_train, y_train)
# Out:
# RandomForestClassifier(criterion='entropy', n_estimators=150, random_state=0)

# %%
y_pred = tree_classifier.predict(X_test)
y_pred
# Out:
# array([4, 4, 1, ..., 6, 6, 2])

# %%
accuracy_score(y_test, y_pred)
# Out:
# 0.818

# %%
from yellowbrick.classifier import ConfusionMatrix
cm = ConfusionMatrix(tree_classifier)
cm.fit(X_train, y_train)
cm.score(X_test, y_test)
# Out:
# 0.818

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.75      0.18      0.29        34
#            1       0.85      0.69      0.76        16
#            2       0.74      0.48      0.58        67
#            3       0.90      0.64      0.75        87
#            4       0.83      0.88      0.85      1230
#            5       0.74      0.85      0.79       156
#            6       0.82      0.79      0.81       910
#
#     accuracy                           0.82      2500
#    macro avg       0.80      0.64      0.69      2500
# weighted avg       0.82      0.82      0.81      2500

# %%
from sklearn.ensemble import ExtraTreesClassifier  
tree_classifier = ExtraTreesClassifier(criterion='entropy', n_estimators=50, random_state=0)
tree_classifier.fit(X_train, y_train)
# Out:
# ExtraTreesClassifier(criterion='entropy', n_estimators=50, random_state=0)

# %%
y_pred = tree_classifier.predict(X_test)
y_pred
# Out:
# array([4, 4, 1, ..., 6, 6, 2])

# %%
accuracy_score(y_test, y_pred)
# Out:
# 0.8212

# %%
from yellowbrick.classifier import ConfusionMatrix
cm = ConfusionMatrix(tree_classifier)
cm.fit(X_train, y_train)
cm.score(X_test, y_test)
# Out:
# 0.8212

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.75      0.35      0.48        34
#            1       0.73      0.69      0.71        16
#            2       0.66      0.46      0.54        67
#            3       0.94      0.71      0.81        87
#            4       0.83      0.88      0.86      1230
#            5       0.73      0.84      0.78       156
#            6       0.83      0.79      0.81       910
#
#     accuracy                           0.82      2500
#    macro avg       0.78      0.68      0.71      2500
# weighted avg       0.82      0.82      0.82      2500
